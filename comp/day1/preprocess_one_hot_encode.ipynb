# %% [markdown]
# ## List fitur categorical
#
# DC025
# DC024
# DC205
# DC206
# DC207
# DC208
# DC209
# DC210
# DC211
# DC212
# DC213
# DC214
# DC215
# DC217
# DC219
# DC226
# DC230a
# DC230b
# DC232
# DC232b
# DC235
# DC237
# DC237b
# DC237c
# DC237d
# DC237e
# DC237f
# DC241
# DC242
# DC244
# DC246
# DC252
# DC270a
# DC109

# %% [markdown]
# ['DC025', 'DC024', 'DC205', 'DC206', 'DC207', 'DC208', 'DC209', 'DC210', 'DC211', 'DC212', 'DC213', 'DC214', 'DC215', 'DC217', 'DC219', 'DC226', 'DC230a', 'DC230b', 'DC232', 'DC232b', 'DC235', 'DC237', 'DC237b', 'DC237c', 'DC237d', 'DC237e', 'DC237f', 'DC241', 'DC242', 'DC244', 'DC246', 'DC252', 'DC270a', 'DC109']

# %%
text = """
DC025
DC024
DC205
DC206
DC207
DC208
DC209
DC210
DC211
DC212
DC213
DC214
DC215
DC217
DC219
DC226
DC230a
DC230b
DC232
DC232b
DC235
DC237
DC237b
DC237c
DC237d
DC237e
DC237f
DC241
DC242
DC244
DC246
DC252
DC270a
DC109"""

# Split the text into lines and remove any empty lines
lines = [line.strip() for line in text.split('\n') if line.strip()]

# Print the resulting list
print(lines)
# Out:
# ['DC025', 'DC024', 'DC205', 'DC206', 'DC207', 'DC208', 'DC209', 'DC210', 'DC211', 'DC212', 'DC213', 'DC214', 'DC215', 'DC217', 'DC219', 'DC226', 'DC230a', 'DC230b', 'DC232', 'DC232b', 'DC235', 'DC237', 'DC237b', 'DC237c', 'DC237d', 'DC237e', 'DC237f', 'DC241', 'DC242', 'DC244', 'DC246', 'DC252', 'DC270a', 'DC109']

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/train.csv")
df_encoded = pd.get_dummies(df, columns=lines)
df_encoded.head()
# Out:
#    id  DC216  DC220  DC237a  DC142a        DC201  DC025_1  DC025_2  DC024_11
# 0   1    1.0   80.0     1.0    60.0  Layak Minum    False     True      True  \
# 1   2    2.0   44.0     1.0    70.0  Layak Minum    False     True      True
# 2   3    2.0   35.0     1.0    75.0  Layak Minum    False     True      True
# 3   6    3.0   79.0     1.0    85.0  Layak Minum    False     True      True
# 4   7    2.0   37.0     1.0    65.0  Layak Minum    False     True      True
#
#    DC024_12  ...  DC270a_5  DC109_11.0  DC109_12.0  DC109_21.0  DC109_31.0
# 0     False  ...     False       False        True       False       False  \
# 1     False  ...     False       False       False       False        True
# 2     False  ...     False        True       False       False       False
# 3     False  ...     False        True       False       False       False
# 4     False  ...     False        True       False       False       False
#
# ...

# %%
df_encoded.to_csv("preprocessed_datasets/encoded_train_df.csv", index=False)
