# %%
# Regular EDA (exploration data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# use pandas to load data into a DataFrame
df = pd.read_csv("../datasets/train.csv")
# df = pd.read_csv("preprocessed_datasets/dropped_nan.csv")
# df = pd.read_csv("preprocessed_datasets/encoded_train_df.csv")
# df_test = pd.read_csv("datasets/test.csv")
# df = pd.read_csv('preprocessed_datasets/mf_df.csv')
print(df.shape) # (rows, columns)
# print(df_test.shape)
# Out:
# (35973, 40)

# %%
df.nunique()
# Out:
# id        35973
# DC024        34
# DC025         2
# DC205         6
# DC206         2
# DC207         2
# DC208         2
# DC209         2
# DC210         2
# DC211         2
# DC212         2
# DC213        10
# DC214        15
# DC215        12
# DC216        15
# DC217         6
# DC219         2
# DC220        84
# DC226        11
# DC230a        5
# DC230b        2
# DC232         2
# DC232b        2
# DC235         3
# DC237         3
# DC237a        3
# DC237b        3
# DC237c        3
# DC237d        3
# DC237e        3
# DC237f        3
# DC241         4
# DC242         2
# DC244         2
# DC246         2
# DC252         5
# DC270a        5
# DC109         9
# DC142a      362
# DC201         2
# dtype: int64

# %%
df['DC109'].unique()
# Out:
# array([12., 31., 11., 41., 32., 21., 51., 33., nan, 96.])

# %%
target_column = 'DC201'

# %%
df.head()
# Out:
#    id  DC216  DC220  DC237a  DC142a        DC201  DC025_1  DC025_2  DC024_11
# 0   1    1.0   80.0     1.0    60.0  Layak Minum    False     True      True  \
# 1   2    2.0   44.0     1.0    70.0  Layak Minum    False     True      True
# 2   3    2.0   35.0     1.0    75.0  Layak Minum    False     True      True
# 3   6    3.0   79.0     1.0    85.0  Layak Minum    False     True      True
# 4   7    2.0   37.0     1.0    65.0  Layak Minum    False     True      True
#
#    DC024_12  ...  DC270a_5  DC109_11.0  DC109_12.0  DC109_21.0  DC109_31.0
# 0     False  ...     False       False        True       False       False  \
# 1     False  ...     False       False       False       False        True
# 2     False  ...     False        True       False       False       False
# 3     False  ...     False        True       False       False       False
# 4     False  ...     False        True       False       False       False
#
#    DC109_32.0  DC109_33.0  DC109_41.0  DC109_51.0  DC109_96.0
# 0       False       False       False       False       False
# 1       False       False       False       False       False
# 2       False       False       False       False       False
# 3       False       False       False       False       False
# 4       False       False       False       False       False
#
# [5 rows x 179 columns]

# %%
df[target_column].replace(to_replace={'Layak Minum':1, 'Tidak Layak Minum':0}, inplace=True)

# %%
# df.drop('id', axis=1, inplace=True)

# %%
df.head()
# Out:
#    id  DC216  DC220  DC237a  DC142a  DC201  DC025_1  DC025_2  DC024_11
# 0   1    1.0   80.0     1.0    60.0    1.0    False     True      True  \
# 1   2    2.0   44.0     1.0    70.0    1.0    False     True      True
# 2   3    2.0   35.0     1.0    75.0    1.0    False     True      True
# 3   6    3.0   79.0     1.0    85.0    1.0    False     True      True
# 4   7    2.0   37.0     1.0    65.0    1.0    False     True      True
#
#    DC024_12  ...  DC270a_5  DC109_11.0  DC109_12.0  DC109_21.0  DC109_31.0
# 0     False  ...     False       False        True       False       False  \
# 1     False  ...     False       False       False       False        True
# 2     False  ...     False        True       False       False       False
# 3     False  ...     False        True       False       False       False
# 4     False  ...     False        True       False       False       False
#
#    DC109_32.0  DC109_33.0  DC109_41.0  DC109_51.0  DC109_96.0
# 0       False       False       False       False       False
# 1       False       False       False       False       False
# 2       False       False       False       False       False
# 3       False       False       False       False       False
# 4       False       False       False       False       False
#
# [5 rows x 179 columns]

# %%
# Potability is the target variable, how many of each class are there?
df[target_column].value_counts()
# Out:
# DC201
# 1.0    32398
# 0.0     3572
# Name: count, dtype: int64

# %%
df[target_column].value_counts().plot(kind="bar", color=["red", "blue"], title = "Layak Minum (1=True, 0=False)");

# %% [markdown]
# | ![image.png](attachment:image.png) ||| ![image-2.png](attachment:image-2.png) ||| ![image-3.png](attachment:image-3.png) |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35973 entries, 0 to 35972
# Columns: 179 entries, id to DC109_96.0
# dtypes: bool(173), float64(5), int64(1)
# memory usage: 7.6 MB

# %%
df.nunique()
# Out:
# id            35973
# DC216            15
# DC220            84
# DC237a            3
# DC142a          362
# DC201             2
# DC025_1           2
# DC025_2           2
# DC024_11          2
# DC024_12          2
# DC024_13          2
# DC024_14          2
# DC024_15          2
# DC024_16          2
# DC024_17          2
# DC024_18          2
# DC024_19          2
# DC024_21          2
# DC024_31          2
# DC024_32          2
# DC024_33          2
# DC024_34          2
# DC024_35          2
# DC024_36          2
# DC024_51          2
# DC024_52          2
# DC024_53          2
# DC024_61          2
# DC024_62          2
# DC024_63          2
# DC024_64          2
# DC024_65          2
# DC024_71          2
# DC024_72          2
# DC024_73          2
# DC024_74          2
# DC024_75          2
# DC024_76          2
# DC024_81          2
# DC024_82          2
# DC024_91          2
# DC024_94          2
# DC205_12.0        2
# DC205_16.0        2
# DC205_17.0        2
# DC205_21.0        2
# DC205_31.0        2
# DC205_96.0        2
# DC206_0.0         2
# DC206_1.0         2
# DC207_0.0         2
# DC207_1.0         2
# DC208_0.0         2
# DC208_1.0         2
# DC209_0.0         2
# DC209_1.0         2
# DC210_0.0         2
# DC210_1.0         2
# DC211_0.0         2
# DC211_1.0         2
# DC212_0.0         2
# DC212_1.0         2
# DC213_11.0        2
# DC213_21.0        2
# DC213_22.0        2
# DC213_31.0        2
# DC213_32.0        2
# DC213_33.0        2
# DC213_34.0        2
# DC213_35.0        2
# DC213_36.0        2
# DC213_96.0        2
# DC214_12.0        2
# DC214_21.0        2
# DC214_22.0        2
# DC214_23.0        2
# DC214_24.0        2
# DC214_25.0        2
# DC214_26.0        2
# DC214_31.0        2
# DC214_32.0        2
# DC214_34.0        2
# DC214_35.0        2
# DC214_36.0        2
# DC214_37.0        2
# DC214_38.0        2
# DC214_96.0        2
# DC215_12.0        2
# DC215_13.0        2
# DC215_21.0        2
# DC215_22.0        2
# DC215_23.0        2
# DC215_31.0        2
# DC215_32.0        2
# DC215_33.0        2
# DC215_34.0        2
# DC215_35.0        2
# DC215_36.0        2
# DC215_96.0        2
# DC217_0           2
# DC217_1           2
# DC217_2           2
# DC217_3           2
# DC217_4           2
# DC217_5           2
# DC219_1           2
# DC219_2           2
# DC226_1.0         2
# DC226_2.0         2
# DC226_3.0         2
# DC226_4.0         2
# DC226_5.0         2
# DC226_6.0         2
# DC226_7.0         2
# DC226_8.0         2
# DC226_9.0         2
# DC226_10.0        2
# DC226_95.0        2
# DC230a_1.0        2
# DC230a_2.0        2
# DC230a_3.0        2
# DC230a_4.0        2
# DC230a_5.0        2
# DC230b_0.0        2
# DC230b_1.0        2
# DC232_0.0         2
# DC232_1.0         2
# DC232b_0.0        2
# DC232b_1.0        2
# DC235_1.0         2
# DC235_2.0         2
# DC235_3.0         2
# DC237_0.0         2
# DC237_1.0         2
# DC237_8.0         2
# DC237b_0.0        2
# DC237b_1.0        2
# DC237b_8.0        2
# DC237c_0.0        2
# DC237c_1.0        2
# DC237c_8.0        2
# DC237d_0.0        2
# DC237d_1.0        2
# DC237d_8.0        2
# DC237e_0.0        2
# DC237e_1.0        2
# DC237e_8.0        2
# DC237f_0.0        2
# DC237f_1.0        2
# DC237f_8.0        2
# DC241_1.0         2
# DC241_2.0         2
# DC241_3.0         2
# DC241_6.0         2
# DC242_0.0         2
# DC242_1.0         2
# DC244_0.0         2
# DC244_1.0         2
# DC246_0.0         2
# DC246_1.0         2
# DC252_0.0         2
# DC252_1.0         2
# DC252_2.0         2
# DC252_3.0         2
# DC252_4.0         2
# DC270a_1          2
# DC270a_2          2
# DC270a_3          2
# DC270a_4          2
# DC270a_5          2
# DC109_11.0        2
# DC109_12.0        2
# DC109_21.0        2
# DC109_31.0        2
# DC109_32.0        2
# DC109_33.0        2
# DC109_41.0        2
# DC109_51.0        2
# DC109_96.0        2
# dtype: int64

# %%
# df.describe() # bisa melihat variabel 'count' terkecil untuk mengetahui berapa banyak data yang NaN
# Out:
#                  id         DC216         DC220        DC237a        DC142a
# count  35973.000000  35934.000000  35969.000000  35936.000000  35921.000000  \
# mean   24336.069775      2.323732     48.475660      0.666045     82.668216
# std    13828.886872      1.105251     13.713263      0.494219     91.194377
# min        1.000000      0.000000     13.000000      0.000000      0.000000
# 25%    12341.000000      2.000000     38.000000      0.000000     42.000000
# 50%    24787.000000      2.000000     48.000000      1.000000     63.000000
# 75%    36131.000000      3.000000     58.000000      1.000000     96.000000
# max    47963.000000     20.000000     98.000000      8.000000    998.000000
#
#               DC201
# count  35970.000000
# mean       0.900695
# std        0.299075
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
pd.set_option('display.max_rows', 179)
df.isna().sum() # dari sini juga terlihat
# Out:
# id             0
# DC216         39
# DC220          4
# DC237a        37
# DC142a        52
# DC201          3
# DC025_1        0
# DC025_2        0
# DC024_11       0
# DC024_12       0
# DC024_13       0
# DC024_14       0
# DC024_15       0
# DC024_16       0
# DC024_17       0
# DC024_18       0
# DC024_19       0
# DC024_21       0
# DC024_31       0
# DC024_32       0
# DC024_33       0
# DC024_34       0
# DC024_35       0
# DC024_36       0
# DC024_51       0
# DC024_52       0
# DC024_53       0
# DC024_61       0
# DC024_62       0
# DC024_63       0
# DC024_64       0
# DC024_65       0
# DC024_71       0
# DC024_72       0
# DC024_73       0
# DC024_74       0
# DC024_75       0
# DC024_76       0
# DC024_81       0
# DC024_82       0
# DC024_91       0
# DC024_94       0
# DC205_12.0     0
# DC205_16.0     0
# DC205_17.0     0
# DC205_21.0     0
# DC205_31.0     0
# DC205_96.0     0
# DC206_0.0      0
# DC206_1.0      0
# DC207_0.0      0
# DC207_1.0      0
# DC208_0.0      0
# DC208_1.0      0
# DC209_0.0      0
# DC209_1.0      0
# DC210_0.0      0
# DC210_1.0      0
# DC211_0.0      0
# DC211_1.0      0
# DC212_0.0      0
# DC212_1.0      0
# DC213_11.0     0
# DC213_21.0     0
# DC213_22.0     0
# DC213_31.0     0
# DC213_32.0     0
# DC213_33.0     0
# DC213_34.0     0
# DC213_35.0     0
# DC213_36.0     0
# DC213_96.0     0
# DC214_12.0     0
# DC214_21.0     0
# DC214_22.0     0
# DC214_23.0     0
# DC214_24.0     0
# DC214_25.0     0
# DC214_26.0     0
# DC214_31.0     0
# DC214_32.0     0
# DC214_34.0     0
# DC214_35.0     0
# DC214_36.0     0
# DC214_37.0     0
# DC214_38.0     0
# DC214_96.0     0
# DC215_12.0     0
# DC215_13.0     0
# DC215_21.0     0
# DC215_22.0     0
# DC215_23.0     0
# DC215_31.0     0
# DC215_32.0     0
# DC215_33.0     0
# DC215_34.0     0
# DC215_35.0     0
# DC215_36.0     0
# DC215_96.0     0
# DC217_0        0
# DC217_1        0
# DC217_2        0
# DC217_3        0
# DC217_4        0
# DC217_5        0
# DC219_1        0
# DC219_2        0
# DC226_1.0      0
# DC226_2.0      0
# DC226_3.0      0
# DC226_4.0      0
# DC226_5.0      0
# DC226_6.0      0
# DC226_7.0      0
# DC226_8.0      0
# DC226_9.0      0
# DC226_10.0     0
# DC226_95.0     0
# DC230a_1.0     0
# DC230a_2.0     0
# DC230a_3.0     0
# DC230a_4.0     0
# DC230a_5.0     0
# DC230b_0.0     0
# DC230b_1.0     0
# DC232_0.0      0
# DC232_1.0      0
# DC232b_0.0     0
# DC232b_1.0     0
# DC235_1.0      0
# DC235_2.0      0
# DC235_3.0      0
# DC237_0.0      0
# DC237_1.0      0
# DC237_8.0      0
# DC237b_0.0     0
# DC237b_1.0     0
# DC237b_8.0     0
# DC237c_0.0     0
# DC237c_1.0     0
# DC237c_8.0     0
# DC237d_0.0     0
# DC237d_1.0     0
# DC237d_8.0     0
# DC237e_0.0     0
# DC237e_1.0     0
# DC237e_8.0     0
# DC237f_0.0     0
# DC237f_1.0     0
# DC237f_8.0     0
# DC241_1.0      0
# DC241_2.0      0
# DC241_3.0      0
# DC241_6.0      0
# DC242_0.0      0
# DC242_1.0      0
# DC244_0.0      0
# DC244_1.0      0
# DC246_0.0      0
# DC246_1.0      0
# DC252_0.0      0
# DC252_1.0      0
# DC252_2.0      0
# DC252_3.0      0
# DC252_4.0      0
# DC270a_1       0
# DC270a_2       0
# DC270a_3       0
# DC270a_4       0
# DC270a_5       0
# DC109_11.0     0
# DC109_12.0     0
# DC109_21.0     0
# DC109_31.0     0
# DC109_32.0     0
# DC109_33.0     0
# DC109_41.0     0
# DC109_51.0     0
# DC109_96.0     0
# dtype: int64

# %%
column_list = list(df.columns)
column_list = column_list[:-1]
# column_list

# %%
row, col = 10, 4
fig, axes = plt.subplots(row, col, figsize=(20, 60))
i, j = 0, 0
for z, column in enumerate(column_list):
    sns.boxplot(ax=axes[i,j], data=df, palette="Set2", x=target_column, y=column_list[z])
    if j == col-1:
        j = 0
        i += 1
    else:
        j += 1

# %% [markdown]
# ### Distribusi data setiap fitur dengan histograms

# %%
target_list = df[target_column].value_counts()
target_list = target_list.index.tolist()
target_list
# Out:
# [1.0, 0.0]

# %%
# Distribution of features

target_value = []

for target in target_list:
    query = str(target_column) + ' == ' + str(target)
    target_value.append(df.query(query))

# colors = ['salmon', 'red', 'blue', 'lightblue', 'orange', 'black', 'gray', 'pink', 'navy', 'white']
colors = ['red', 'blue']

fig = plt.figure(figsize=(20,20))

for ax,column in enumerate(df.columns[:39]):
    plt.subplot(10,4,ax+1)
    plt.title(f'Distribution of {column} values')
    for i, target in enumerate(target_value):
        sns.histplot(x=target[column],label=target_list[i], color=colors[i])    
    plt.legend(prop=dict(size=10))

    
plt.tight_layout()

# %%
# sns.pairplot(df, hue=target_column)

# %% [markdown]
# ### Correlation Matrix

# %%
df_drop_na = df.dropna()

# %%
# Use Seaborn to make a correlation matrix
corr_matrix = df_drop_na.corr()
fig, ax = plt.subplots(figsize=(25,25))
ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt=".2f",
                cmap="YlGnBu");

# %% [markdown]
# ## Feature Importance (do after imputation)

# %%
from sklearn.model_selection import train_test_split

y = np.array(df_drop_na[target_column])
df_dropped = df_drop_na.drop(target_column, axis=1) # drop target
X = np.array(df_dropped)

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

feature_names = [f"feature {i}" for i in range(X.shape[1])]
forest = RandomForestClassifier(random_state=0)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ### mean decrease in impurity

# %%
import time
import numpy as np

start_time = time.time()
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
elapsed_time = time.time() - start_time

print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")
# Out:
# Elapsed time to compute the importances: 0.021 seconds

# %%
forest_importances = pd.Series(importances, index=feature_names)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# 0, 16, 37 using dropna()

# %% [markdown]
# 0, 2, 11, 16, 22, 36, 37 after imputation

# %%
important_features_df = df.iloc[:, [0,2,11,16,22,36,37]]
important_features_df
# Out:
#        DC024  DC205  DC214  DC220     DC235  DC109  DC142a
# 0       11.0   16.0   36.0   80.0  1.000000   12.0    60.0
# 1       11.0   31.0   36.0   44.0  1.000000   31.0    70.0
# 2       11.0   12.0   36.0   35.0  1.000000   11.0    75.0
# 3       11.0   12.0   36.0   79.0  1.000000   11.0    85.0
# 4       11.0   12.0   36.0   37.0  1.000000   11.0    65.0
# ...      ...    ...    ...    ...       ...    ...     ...
# 35965   94.0   17.0   24.0   21.0  3.000000   21.0     9.0
# 35966   94.0   12.0   32.0   41.0  1.951290   11.0    12.0
# 35967   94.0   12.0   24.0   52.0  2.073468   11.0    48.0
# 35968   94.0   12.0   32.0   58.0  1.969629   11.0    39.0
# 35969   94.0   12.0   32.0   31.0  2.070088   11.0    40.0
#
# [35970 rows x 7 columns]

# %%
important_features_df.loc[:, [target_column]] = df.loc[:, [target_column]].values
important_features_df
# Out:
#        DC024  DC205  DC214  DC220     DC235  DC109  DC142a  DC201
# 0       11.0   16.0   36.0   80.0  1.000000   12.0    60.0    1.0
# 1       11.0   31.0   36.0   44.0  1.000000   31.0    70.0    1.0
# 2       11.0   12.0   36.0   35.0  1.000000   11.0    75.0    1.0
# 3       11.0   12.0   36.0   79.0  1.000000   11.0    85.0    1.0
# 4       11.0   12.0   36.0   37.0  1.000000   11.0    65.0    1.0
# ...      ...    ...    ...    ...       ...    ...     ...    ...
# 35965   94.0   17.0   24.0   21.0  3.000000   21.0     9.0    1.0
# 35966   94.0   12.0   32.0   41.0  1.951290   11.0    12.0    1.0
# 35967   94.0   12.0   24.0   52.0  2.073468   11.0    48.0    1.0
# 35968   94.0   12.0   32.0   58.0  1.969629   11.0    39.0    1.0
# 35969   94.0   12.0   32.0   31.0  2.070088   11.0    40.0    1.0
#
# [35970 rows x 8 columns]

# %%
important_features_df.to_csv('preprocessed_datasets/important_features.csv', index=False)

# %% [markdown]
# ### feature permutation

# %%
# from sklearn.inspection import permutation_importance

# start_time = time.time()
# result = permutation_importance(
#     forest, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
# )
# elapsed_time = time.time() - start_time
# print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")

# forest_importances = pd.Series(result.importances_mean, index=feature_names)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# fig, ax = plt.subplots()
# forest_importances.plot.bar(yerr=result.importances_std, ax=ax)
# ax.set_title("Feature importances using permutation on full model")
# ax.set_ylabel("Mean accuracy decrease")
# fig.tight_layout()
# plt.show()

# %% [markdown]
# # Insights
#
# NaN data
#
# ![image.png](attachment:image.png)
#
# feature importance mean decrease
#
# ![image-2.png](attachment:image-2.png)
#
# feature importance permutation
#
# OOM
