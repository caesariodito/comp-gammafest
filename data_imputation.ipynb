# %% [markdown]
# ## Mice and KNN Method
#
# ### Mice
# ![image.png](attachment:image.png)
#
# ### KNN
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Data

# %%
import pandas as pd

# use pandas to load data into a DataFrame
df = pd.read_csv("water_potability.csv")
df.shape # (rows, columns)
# Out:
# (3276, 10)

# %% [markdown]
# #### Mice
#
# Linear Regression pada masing - masing featrue
#
# ```python
# import numpy as np
# from sklearn.experimental import enable_iterative_imputer
# from sklearn.impute import IterativeImputer
# from sklearn.linear_model import LinearRegression
#
# lr = LinearRegression()
# imp = IterativeImputer(estimator=lr,missing_values=np.nan, max_iter=10, verbose=2, imputation_order='roman',random_state=0)
# X=imp.fit_transform(X)
# ```

# %%
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
imp = IterativeImputer(estimator=lr,missing_values=np.nan, max_iter=10, verbose=2, imputation_order='roman',random_state=0)
X=imp.fit_transform(df)
# Out:
# [IterativeImputer] Completing matrix with shape (3276, 10)
# [IterativeImputer] Ending imputation round 1/10, elapsed time 0.03
# [IterativeImputer] Change: 41.78784423458126, scaled tolerance: 61.22719600771214
# [IterativeImputer] Early stopping criterion reached.

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate
# 0          NaN  204.890455  20791.318981     7.300212  368.516441  \
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
MICE_df = pd.DataFrame(X, columns=df.columns)
MICE_df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate
# 0     7.199101  204.890455  20791.318981     7.300212  368.516441  \
# 1     3.716080  129.422921  18630.057858     6.635246  344.894384
# 2     8.099124  224.236259  19909.541732     9.275884  334.706620
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  340.951154
# 3273  9.419510  175.762646  33155.578218     7.350233  326.676061
# 3274  5.126763  230.603758  11983.869376     6.303357  332.463189
# 3275  7.874671  195.102299  17404.177061     7.509306  338.844127
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135         0.0
# ...

# %% [markdown]
# ### MICE Forest

# %%
import miceforest as mf

# %%
# Create kernel. 
kds = mf.ImputationKernel(
  df,
  save_all_iterations=True,
  random_state=100
)

# Run the MICE algorithm for 2 iterations
kds.mice(2)

# Return the completed dataset.
mf_df = kds.complete_data()

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate
# 0          NaN  204.890455  20791.318981     7.300212  368.516441  \
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
mf_df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate
# 0     7.368769  204.890455  20791.318981     7.300212  368.516441  \
# 1     3.716080  129.422921  18630.057858     6.635246  347.062241
# 2     8.099124  224.236259  19909.541732     9.275884  305.382914
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  320.846507
# 3273  9.419510  175.762646  33155.578218     7.350233  300.254258
# 3274  5.126763  230.603758  11983.869376     6.303357  332.196048
# 3275  7.874671  195.102299  17404.177061     7.509306  350.401849
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
kds.mice(iterations=5, n_estimators=50)
mf_df_2 = kds.complete_data()

# %%
mf_df_2.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity
# 0  7.833971  204.890455  20791.318981     7.300212  368.516441    564.308654  \
# 1  3.716080  129.422921  18630.057858     6.635246  356.756191    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  312.919044    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# #### KNN
#
# Nearest Neighbors
#
# ```python
# from sklearn.impute import KNNImputer
# knn = KNNImputer(n_neighbors=2, add_indicator=True)
# knn.fit(X)
# knn.transform(X)
# ```

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# Create an instance of KNNImputer
imputer = KNNImputer(n_neighbors=2)

# Fit and transform the dataframe
knn_df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate
# 0          NaN  204.890455  20791.318981     7.300212  368.516441  \
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
knn_df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate
# 0     6.007427  204.890455  20791.318981     7.300212  368.516441  \
# 1     3.716080  129.422921  18630.057858     6.635246  326.479827
# 2     8.099124  224.236259  19909.541732     9.275884  357.947334
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  355.544770
# 3273  9.419510  175.762646  33155.578218     7.350233  321.930158
# 3274  5.126763  230.603758  11983.869376     6.303357  338.733772
# 3275  7.874671  195.102299  17404.177061     7.509306  335.431261
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135         0.0
# ...

# %% [markdown]
# ## Export Imputed DataFrame to csv

# %%
mf_df_2.to_csv('mf_df_2_imputed_water_potability.csv', index=False)
