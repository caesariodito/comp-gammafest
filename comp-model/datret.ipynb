# %% [markdown]
# # Breast Cancer with Datret (Tensorflow)
#
# Datret: Tensorflow implementation for structured tabular data.
#
# A simple implementation of a deep neural network architecture for tabular data with automatic layer-by-layer reduction in the number of neurons and functionality similar to classical machine learning methods.
#
# source: https://github.com/AbdualimovTP/datret
#
# ---
#
# Architecture:
# ```text
# Model: "DatRet with number_neurons = 500"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, X_train.shape[0)]      0
#
#  dense (Dense)               (None, 500)               150500
#
#  dense_1 (Dense)             (None, 250)               125250
#
#  dense_2 (Dense)             (None, 125)               31375
#
#  dense_3 (Dense)             (None, 62)                7812
#
#  dense_4 (Dense)             (None, 31)                1953
#
#  dense_5 (Dense)             (None, 15)                480
#
#  dense_6 (Dense)             (None, 7)                 112
#
#  dense_7 (Dense)             (None, 3)                 24
#
#  dense_8 (Dense)             (None, 2)                 8
#                        (2 predictable classes)
# =================================================================
# Total params: 317,514
# Trainable params: 317,514
# Non-trainable params: 0
# ```
# ---

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report

from sklearn.model_selection import train_test_split
from fast_ml.model_development import train_valid_test_split

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError, BinaryCrossentropy
from datret.datret import DatRetClassifier, DatRetRegressor, DatRetMultilabelClassifier

# %%
# Random Seed
random_seed = 42 # set random seed for reproducibility
tf.random.set_seed(random_seed) # set random seed for TensorFlow
np.random.seed(random_seed) # set random seed for NumPy

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('datasets/mf_df_2_breast_cancer.csv')
df
# Out:
#           Id  Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape
# 0    1000025                5                     1                      1  \
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
#      Marginal_adhesion  Single_e_cell_size  Bare_nuclei  Bland_chromatin
# 0                    1                   2          1.0                3  \
# 1                    5                   7         10.0                3
# 2                    1                   2          2.0                3
# 3                    1                   3          4.0                3
# 4                    3                   2          1.0                3
# ..                 ...                 ...          ...              ...
# 694                  1                   3          2.0                1
# 695                  1                   2          1.0                1
# 696                  3                   7          3.0                8
# 697                  4                   3          4.0               10
# 698                  5                   4          5.0               10
#
#      Normal_nucleoli  Mitoses  Class
# 0                  1        1      2
# 1                  2        1      2
# 2                  1        1      2
# 3                  7        1      2
# 4                  1        1      2
# ..               ...      ...    ...
# 694                1        1      2
# 695                1        1      2
# 696               10        2      4
# 697                6        1      4
# 698                4        1      4
#
# [699 rows x 11 columns]

# %%
target_column='Class'

# %%
df[target_column].replace(to_replace={2:0, 4:1}, inplace=True)

# %%
df[:3]
# Out:
#         Id  Clump_thickness  Uniformity_cell_size  Uniformity_cell_shape
# 0  1000025                5                     1                      1  \
# 1  1002945                5                     4                      4
# 2  1015425                3                     1                      1
#
#    Marginal_adhesion  Single_e_cell_size  Bare_nuclei  Bland_chromatin
# 0                  1                   2          1.0                3  \
# 1                  5                   7         10.0                3
# 2                  1                   2          2.0                3
#
#    Normal_nucleoli  Mitoses  Class
# 0                1        1      0
# 1                2        1      0
# 2                1        1      0

# %%
y = np.array(df[target_column]) # value dari label
df = df.drop(target_column, axis=1) # drop target
X = np.array(df) # df dalam bentuk numpy array

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# X_train, y_train, X_valid, y_valid, X_test, y_test = train_valid_test_split(df, target=target_column, train_size=0.8, valid_size=0.1, test_size=0.1)

# %%
print(X_train.shape, y_train.shape)
# print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)
# Out:
# (559, 10) (559,)
# (140, 10) (140,)

# %%
# scaler = StandardScaler()
scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_valid = scaler.fit_transform(X_valid)
X_test = scaler.fit_transform(X_test)

# %%
temp = pd.DataFrame(X_train)
temp[:3]
# Out:
#           0         1         2         3         4         5         6
# 0  0.080816  0.444444  0.111111  0.000000  0.000000  0.111111  0.000000  \
# 1  0.078163  0.444444  0.222222  0.222222  0.333333  0.111111  0.333333
# 2  0.086815  0.000000  0.000000  0.000000  0.111111  0.111111  0.000000
#
#           7         8    9
# 0  0.222222  0.000000  0.0
# 1  0.222222  0.333333  0.0
# 2  0.222222  0.000000  0.0

# %% [markdown]
# ## Modeling

# %%
# Call the regressor or classifier and train the model.
DR = DatRetClassifier(epoch=50,
                      optimizer=Nadam(learning_rate=0.001),
                      loss=BinaryCrossentropy(),
                      verbose=1,
                      number_neurons=1000,
                      validation_split = 0.2,
                      batch_size=100,
                      shuffle=True,
                      callback=[]
                      )

DR.fit(X_train, y_train)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 4s 85ms/step - loss: 0.6131 - val_loss: 0.5085
# Epoch 2/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.4521 - val_loss: 0.4319
# Epoch 3/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3895 - val_loss: 0.3938
# Epoch 4/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3343 - val_loss: 0.3475
# Epoch 5/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2883 - val_loss: 0.3064
# Epoch 6/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2394 - val_loss: 0.2738
# Epoch 7/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1996 - val_loss: 0.2786
# Epoch 8/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1749 - val_loss: 0.2237
# Epoch 9/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.1289 - val_loss: 0.1895
# Epoch 10/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.1102 - val_loss: 0.1810
# Epoch 11/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0931 - val_loss: 0.1534
# Epoch 12/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0957 - val_loss: 0.1591
# Epoch 13/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0869 - val_loss: 0.1704
# Epoch 14/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0811 - val_loss: 0.1553
# Epoch 15/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0799 - val_loss: 0.1481
# Epoch 16/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0878 - val_loss: 0.1457
# Epoch 17/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0783 - val_loss: 0.1680
# Epoch 18/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0920 - val_loss: 0.1484
# Epoch 19/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0830 - val_loss: 0.1430
# Epoch 20/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0780 - val_loss: 0.1396
# Epoch 21/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0731 - val_loss: 0.1404
# Epoch 22/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0810 - val_loss: 0.1386
# Epoch 23/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0708 - val_loss: 0.1406
# Epoch 24/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0679 - val_loss: 0.1369
# Epoch 25/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0675 - val_loss: 0.1425
# Epoch 26/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0658 - val_loss: 0.1451
# Epoch 27/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0643 - val_loss: 0.1405
# Epoch 28/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0643 - val_loss: 0.1408
# Epoch 29/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0612 - val_loss: 0.1485
# Epoch 30/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0708 - val_loss: 0.1606
# Epoch 31/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0706 - val_loss: 0.1458
# Epoch 32/50
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0685 - val_loss: 0.1395
# Epoch 33/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0665 - val_loss: 0.1543
# Epoch 34/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0626 - val_loss: 0.1488
# Epoch 35/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0624 - val_loss: 0.1515
# Epoch 36/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0590 - val_loss: 0.1423
# Epoch 37/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0599 - val_loss: 0.1503
# Epoch 38/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0599 - val_loss: 0.1509
# Epoch 39/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0598 - val_loss: 0.1563
# Epoch 40/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0572 - val_loss: 0.1595
# Epoch 41/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0574 - val_loss: 0.1537
# Epoch 42/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0562 - val_loss: 0.1789
# Epoch 43/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0544 - val_loss: 0.1767
# Epoch 44/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0544 - val_loss: 0.1964
# Epoch 45/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0541 - val_loss: 0.1909
# Epoch 46/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0542 - val_loss: 0.2013
# Epoch 47/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0528 - val_loss: 0.1983
# Epoch 48/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0531 - val_loss: 0.1986
# Epoch 49/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0542 - val_loss: 0.2087
# Epoch 50/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0536 - val_loss: 0.1524

# %% [markdown]
# ## Model Evaluation

# %%
# predict the actual label (or class) over a new set of data.
DR_predict = DR.predict(X_test)

# predict the class probabilities for each data point.
DR_predict_proba = DR.predict_proba(X_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step
# 5/5 [==============================] - 0s 2ms/step

# %%
cr = classification_report(y_test, DR_predict)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94        95
#            1       0.97      0.78      0.86        45
#
#     accuracy                           0.92       140
#    macro avg       0.94      0.88      0.90       140
# weighted avg       0.93      0.92      0.92       140
